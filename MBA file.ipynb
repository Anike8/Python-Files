# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/admin/Downloads/mba.csv")

# %%
df
# Out:
#      datasrno  workex  gmat
# 0           1      21   720
# 1           2     107   640
# 2           3      57   740
# 3           4      99   690
# 4           5     208   710
# ..        ...     ...   ...
# 768       769      88   620
# 769       770     132   670
# 770       771      28   610
# 771       772      10   610
# 772       773      52   620
#
# [773 rows x 3 columns]

# %%
df.shape
# Out:
# (773, 3)

# %%
df.size
# Out:
# 2319

# %%
df.describe()
# Out:
#         datasrno     workex        gmat
# count  773.00000  773.00000  773.000000
# mean   387.00000   57.50194  711.164295
# std    223.29017   27.38682   29.339714
# min      1.00000    9.00000  600.000000
# 25%    194.00000   41.00000  690.000000
# 50%    387.00000   52.00000  710.000000
# 75%    580.00000   69.00000  730.000000
# max    773.00000  279.00000  780.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['workex'])
plt.title('Workex')
# Out:
# Text(0.5, 1.0, 'Workex')

# %%
sns.barplot(x='datasrno',y='workex',data=df)
# Out:
# <AxesSubplot:xlabel='datasrno', ylabel='workex'>

# %%
df['workex'].value_counts()
# Out:
# 45     60
# 33     44
# 57     42
# 69     41
# 44     41
#        ..
# 136     1
# 176     1
# 111     1
# 175     1
# 10      1
# Name: workex, Length: 112, dtype: int64

# %%
df['workex'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='workex'>

# %%
sns.boxplot('workex',data=df)
plt.title('BOX PLOT',size=30)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'BOX PLOT')

# %%
sns.stripplot(x='workex',y='gmat',data=df)
# Out:
# <AxesSubplot:xlabel='workex', ylabel='gmat'>

# %%
ff= df.loc[df['gmat']>650,'workex'].dropna()
sns.distplot(ff)
plt.title('WORKEX')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'WORKEX')

# %%
ff= df.loc[df['workex']>200,'gmat'].dropna()
sns.distplot(ff)
plt.title('GMAT')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'GMAT')

# %%
sns.violinplot(x='workex',y='gmat',data=df)
plt.show()

# %%
sns.scatterplot(x='workex',y='gmat',data=df)
# Out:
# <AxesSubplot:xlabel='workex', ylabel='gmat'>

# %%
sns.jointplot(x='workex',y='gmat',data=df,kind='kde')

# %%
sns.violinplot(x='workex',y='gmat',data=df)
sns.stripplot(x='workex',y='gmat',data=df)
plt.show()

# %%
df.describe()
# Out:
#         datasrno     workex        gmat
# count  773.00000  773.00000  773.000000
# mean   387.00000   57.50194  711.164295
# std    223.29017   27.38682   29.339714
# min      1.00000    9.00000  600.000000
# 25%    194.00000   41.00000  690.000000
# 50%    387.00000   52.00000  710.000000
# 75%    580.00000   69.00000  730.000000
# max    773.00000  279.00000  780.000000

# %%
df
# Out:
#      datasrno  workex  gmat
# 0           1      21   720
# 1           2     107   640
# 2           3      57   740
# 3           4      99   690
# 4           5     208   710
# ..        ...     ...   ...
# 768       769      88   620
# 769       770     132   670
# 770       771      28   610
# 771       772      10   610
# 772       773      52   620
#
# [773 rows x 3 columns]

# %%
from scipy import stats

# %%
stats.norm.cdf(680,711,29)
# Out:
# 0.14254260383881612

# %%
stats.norm.cdf(720,711,29)
# Out:
# 0.621850627348053

# %%
1-stats.norm.cdf(720,711,29)
# Out:
# 0.37814937265194704

# %%
stats.norm.cdf(680,711,29)
# Out:
# 0.14254260383881612

# %%
stats.norm.cdf(740,711,29)-stats.norm.cdf(680,711,29)
# Out:
# 0.6988021422297268
